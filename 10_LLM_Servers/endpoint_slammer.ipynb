# %% [markdown]
# Now that you've deployed your endpoint - it's time to slam it!

# %%
import os
import getpass
from dotenv import load_dotenv

load_dotenv()

if not os.environ.get("FIREWORKS_API_KEY"):
    os.environ["FIREWORKS_API_KEY"] = getpass.getpass("Enter your Fireworks API key: ")

if not os.environ.get("FIREWORKS_CHAT_MODEL"):
    os.environ["FIREWORKS_CHAT_MODEL"] = getpass.getpass("Enter your Fireworks chat model: ")

# %% [markdown]
# Let's try with 1 request, just to verify our endpoint is alive.
#
# Make sure you provide your own endpoint identifier! It will look something like this:
#
# - `accounts/fireworks/models/gpt-oss-20b` (serverless)
# - Or your custom on-demand deployment identifier

# %%
from langchain_fireworks import ChatFireworks

# REPLACE WITH YOUR OWN ENDPOINT IDENTIFIER
model_endpoint = os.environ.get("FIREWORKS_CHAT_MODEL")

llm = ChatFireworks(model=model_endpoint)

response = llm.invoke("How much wood could a wood chuck chuck if a wood chuck could chuck wood?")
print(response.content)
# Out:
# **Classic answer:**
# A wood‑chuck would chuck **as much wood as a wood‑chuck could chuck, if a wood‑chuck could chuck wood.**
# — the original tongue‑twister simply has an **I‑with‑a‑t** rhyme, not a physics problem.
#
# ---
#
# ## The “real” answer: a playful estimation
#
# In 1988 a student at the University of Chicago – and later a team at Purdue – did a tongue‑in‑cheek experiment to answer the question scientifically. They measured how much earth a woodchuck (groundhog) typically moves when excavating a burrow and then applied that to the density of wood. They came up with a figure of about **700 pounds** (≈ 317 kg) of wood, or roughly **50–55 cubic feet** of solid hardwood, per day (assuming the wood was chopped into manageable pieces).
#
# Key points from that study:
# - **Burrow volume:** ~200 cubic feet per sheet.
# - **Feasible chunk size:** ~20‑30 lb per hand‑hold.
# - **Daily “chuck”:** ~24–30 chunks → ~600–900 lb.
#
# So, if a woodchuck could actually pick up wood and throw it, a **700‑lb** limit is a fun “rule of thumb.”
#
# ---
#
# ## Bottom line
#
# - **Tongue‑twister:** “as much wood… as a woodchuck could chuck, if a woodchuck could chuck wood.”
# - **Scientific throwback:** ~700 lb (≈ 50 ft³) of wood per day, based on digging data.
#
# Either way, the real puzzle is that the woodchuck would probably be more interested in finding a comfy burrow than performing a wood‑chuck marathon. 🌰🪵

# %% [markdown]
# Now, let's SLAM IT.

# %%
import asyncio

async def send_request(llm, idx):
    try:
        response = await llm.ainvoke(
            f"How much wood could a wood chuck chuck if a wood chuck could chuck wood? (Request {idx})"
        )
        print(f"Response {idx}: {response.content[:60]}...")
    except Exception as e:
        print(f"Request {idx} failed: {e}")

async def main():
    tasks = [send_request(llm, i) for i in range(1, 25)]
    await asyncio.gather(*tasks)

await main()
# Out:
# Response 7: A woodchuck would chuck as much wood as a woodchuck could ch...
# Response 13: According to the **tongue‑twister lore**, a woodchuck (also ...
# Response 8: Little green the eponymous chuck is a delightful tongue‑twis...
# Response 15: How much wood could a wood‑chuck chuck if a wood‑chuck could...
# Response 9: I’m not a wood‑chuck, but the folklore says that a wood–chuc...
# Response 1: The tongue‑twister’s charm comes more from its rhythm than f...
# Response 21: A classic tongue‑twister, and one that has inspired both jok...
# Response 22: A classic tongue‑twister, and the answer is more whimsical t...
# Response 23: Ah, the classic tongue‑twister! 🎶
#
# > **“How much wood would ...
# Response 16: **Answer (Request 16)**
# The classic tongue‑twister really ...
# Response 11: The correct answer is 0....
# Response 4: The classic tongue‑twister “How much wood could a woodchuck ...
# Response 17: It’s a tongue‑twister, a bit of folklore, and a good laugh a...
# Response 19: Ah, the classic tongue‑twister! While it’s all in good fun, ...
# Response 6: **Answer to Request 6**
#
# That old tongue‑twister comes with ...
# Response 12: Hard to say exactly—woodchucks (also called groundhogs) are ...
# Response 24: It’s a classic tongue‑twister, not a science‑experiment!  Ac...
# Response 14: The classic tongue‑twister “How much wood would a woodchuck ...
# Response 18: **Answer – the classic tongue‑twister plus a dash of science...
# Response 10: **How much wood could a wood‑chuck chuck if a wood‑chuck cou...
# Response 5: **Answer (Request 5)**
#
# > **How much wood could a *woodchu...
# Response 3: That classic rhyme doesn’t hide a real physics problem – it’...
# Response 2: 😂 **“How much wood could a wood‑chuck chuck…”**
# It’s one o...
# Response 20: A woodchuck would chuck about 700 pounds of wood—nearly the ...
