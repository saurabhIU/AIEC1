# %% [markdown]
# # Your First Vector RAG Application: Cat Health Assistant
#
# In this notebook, we will build a dense vector retrieval application using **LangChain v1**, **OpenAI embeddings**, and **Qdrant** as an in-memory vector database.
#
# The goal is to understand the core RAG loop:
#
# 1. Load a cat health guideline PDF
# 2. Split it into smaller chunks
# 3. Embed those chunks
# 4. Store the embeddings in Qdrant
# 5. Retrieve relevant chunks for a question
# 6. Generate an answer grounded in the retrieved context
#
# > Note: This notebook expects Python 3.12 and uses uv for dependency management.
#
# > Note: This is a vector RAG lesson, not a veterinary care tool. The assistant should answer from the PDF and point users to a veterinarian for diagnosis, treatment, medication, or urgent care decisions.

# %% [markdown]
# ## Table of Contents
#
# - Task 1: Environment Setup
# - Task 2: Embedding Similarity Primer
# - Task 3: Documents - Loading the Cat Health Guideline PDF
# - Task 4: Chunking the Documents
# - Task 5: Embeddings and Qdrant
# - Task 6: Retrieval with Scores
# - Task 7: Retrieval Augmented Generation
# - Activity: Tune Retrieval Quality

# %% [markdown]
# ## Task 1: Environment Setup
#
# From the `01_Dense_Vector_Retrieval` folder, install dependencies with uv:
#
# ```bash
# uv sync
# ```
#
# Then open this notebook in Cursor or VS Code and select the Python/Jupyter environment created by uv.

# %% [markdown]
# ### Imports
#
# LangChain v1 separates integrations into partner packages. We will use:
#
# - `langchain_community` for PDF loading
# - `langchain_text_splitters` for chunking
# - `langchain_openai` for chat and embedding models
# - `langchain_qdrant` for the Qdrant vector store

# %%
from pathlib import Path
from math import sqrt
from getpass import getpass
import os

from langchain_community.document_loaders import PyPDFLoader
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI, OpenAIEmbeddings
from langchain_qdrant import QdrantVectorStore
from langchain_text_splitters import RecursiveCharacterTextSplitter

# %% [markdown]
# ### OpenAI API Key
#
# The chat model and embedding model both use OpenAI. If `OPENAI_API_KEY` is not already set in your environment, this cell will ask for it securely.

# %%
if not os.environ.get("OPENAI_API_KEY"):
    os.environ["OPENAI_API_KEY"] = getpass("OpenAI API Key: ")

# %% [markdown]
# ## Task 2: Embedding Similarity Primer
#
# Before we load a full PDF, let's make dense vector retrieval less mysterious.
#
# An embedding model turns text into a list of numbers. Texts with related meaning should land closer together in that vector space.
#
# A common way to score closeness is **cosine similarity**:
#
# ```text
# cosine_similarity(a, b) = dot_product(a, b) / (length(a) * length(b))
# ```
#
# The intuition: if two vectors point in a similar direction, their cosine similarity is higher. Vector databases like Qdrant use this same idea, but at a much larger scale.

# %%
embedding_model = "text-embedding-3-small"
embeddings = OpenAIEmbeddings(model=embedding_model)

example_texts = [
    "king",
    "queen",
    "banana",
    "cat",
    "veterinarian",
    "cat health guidelines",
]

example_vectors = dict(zip(example_texts, embeddings.embed_documents(example_texts)))


def cosine_similarity(vector_a: list[float], vector_b: list[float]) -> float:
    dot_product = sum(a * b for a, b in zip(vector_a, vector_b))
    length_a = sqrt(sum(a * a for a in vector_a))
    length_b = sqrt(sum(b * b for b in vector_b))
    return dot_product / (length_a * length_b)


comparison_pairs = [
    ("king", "queen"),
    ("king", "banana"),
    ("cat", "veterinarian"),
    ("cat", "cat health guidelines"),
]

for left, right in comparison_pairs:
    score = cosine_similarity(example_vectors[left], example_vectors[right])
    print(f"{left:>22} <> {right:<22} score={score:.3f}")
# Out:
#                   king <> queen                  score=0.591
#                   king <> banana                 score=0.310
#                    cat <> veterinarian           score=0.356
#                    cat <> cat health guidelines  score=0.496

# %% [markdown]
# A few important notes:
#
# - The score is useful for ranking, not as an absolute truth about meaning.
# - Different embedding models can produce different scores.
# - In RAG, we embed each document chunk once, then embed the user's query and search for the nearest chunk vectors.
#
# That is the retrieval part of RAG.

# %% [markdown]
# ## Task 3: Documents
#
# LangChain represents loaded text as `Document` objects. A `Document` has:
#
# - `page_content`: the text
# - `metadata`: information such as source file and page number
#
# We will load one `Document` per PDF page, then split those pages into smaller chunks.

# %% [markdown]
# ### Course PDF
#
# This notebook uses the bundled cat health guideline PDF at:
#
# ```text
# 01_Dense_Vector_Retrieval/data/cat_health_guidelines.pdf
# ```
#
# The next cell checks that the course material is present before we start loading pages.

# %%
pdf_path = Path("data/cat_health_guidelines.pdf")

if not pdf_path.exists():
    raise FileNotFoundError(
        f"Expected the cat health guideline PDF at: {pdf_path.resolve()}\n"
        "The bundled course PDF is missing from this copy of the materials."
    )

# %% [markdown]
# ### Load the PDF
#
# `PyPDFLoader` extracts text from text-based PDFs. If the PDF is scanned images, this loader may return little or no text, and OCR would be needed.

# %%
loader = PyPDFLoader(str(pdf_path))
pages = loader.load()

for page in pages:
    page.metadata["source"] = pdf_path.name
    page.metadata["document_type"] = "cat_health_guideline"

pages = [page for page in pages if page.page_content.strip()]

if not pages:
    raise ValueError(
        "The PDF loaded, but no extractable text was found. "
        "This usually means the PDF is scanned and needs OCR first."
    )

print(f"Loaded {len(pages)} text-containing PDF pages.")
# Out:
# Loaded 22 text-containing PDF pages.

# %%
print(pages[0].page_content[:750])
print("\nMetadata:", pages[0].metadata)
# Out:
# VETERINARY PRACTICE GUIDELINES
# 2021 AAHA/AAFP Feline Life Stage Guidelines*
# Jessica Quimby, DVM, PhD, DACVIM y, Shannon Gowland, DVM, DABVP y, Hazel C. Carney, DVM, MS, DABVP,
# Theresa DePorter, DVM, MRCVS, DACVB, DECAWBM, Paula Plummer, LVT, VTS (ECC, SAIM), Jodi Westropp,
# DVM, PhD, DACVIM
# ABSTRACT
# The guidelines, authored by a Task Force ofexperts in feline clinical medicine, are an update and extension of the AAFP–AAHA
# Feline Life Stage Guidelines published in 2010. The guidelines are published simultaneously in theJournal of Feline Medicine and
# Surgery(volume 23, issue 3, pages 211–233, DOI: 10.1177/1098612X21993657) and theJournal of the American Animal Hospital
# Association(volume 57, issue 2, pages 51–72, DOI: 10.5326/JAAHA-MS-7189). A
#
# Metadata: {'producer': 'Acrobat Distiller 10.0.0 (Windows)', 'creator': 'Adobe InDesign CS6 (Windows)', 'creationdate': '2021-02-02T08:52:15-05:00', 'author': '7123', 'moddate': '2021-02-02T07:53:51-07:00', 'title': 'djs_jaaha_56_5_COVER.indd', 'source': 'cat_health_guidelines.pdf', 'total_pages': 22, 'page': 0, 'page_label': '1', 'document_type': 'cat_health_guideline'}

# %% [markdown]
# #### ❓Question #1
#
# Why is metadata important for a RAG application?
#
# ##### ✅ Answer:
#
# Metadata is important in a RAG application because they capture context and business information. Lets say for cat doument, if we tag relevant section names into metadata like Life Stage, Behaviour and environment needs etc. it would be easier to retrieve rellevant documents inspite of whole vector db scan. It also adds flexibility for retrieval based on certain time window like lets say a particular document section expires after a certain time and metadata can tell retrieval to ignore that section during retrieval process

# %% [markdown]
# ## Task 4: Chunking the Documents
#
# A full PDF page can be too large or too mixed-topic for high-quality retrieval. We split pages into overlapping chunks so each chunk has enough local context but is still focused.
#
# Here we will start with chunks of 1,000 characters and 200 characters of overlap. The chunk size controls how much text each vector represents; the overlap keeps nearby context from being lost at chunk boundaries.
#
# `RecursiveCharacterTextSplitter` tries to split on natural boundaries first, such as paragraphs and line breaks, before falling back to smaller separators.

# %%
chunk_size = 1000
chunk_overlap = 200

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=chunk_size,
    chunk_overlap=chunk_overlap,
    add_start_index=True,
)

splits = text_splitter.split_documents(pages)

print(f"Split {len(pages)} pages into {len(splits)} chunks.")
print(f"Chunk size: {chunk_size} characters")
print(f"Chunk overlap: {chunk_overlap} characters")
# Out:
# Split 22 pages into 135 chunks.
# Chunk size: 1000 characters
# Chunk overlap: 200 characters

# %%
sample_chunk = splits[0]
print(sample_chunk.page_content[:750])
print("\nMetadata:", sample_chunk.metadata)
# Out:
# VETERINARY PRACTICE GUIDELINES
# 2021 AAHA/AAFP Feline Life Stage Guidelines*
# Jessica Quimby, DVM, PhD, DACVIM y, Shannon Gowland, DVM, DABVP y, Hazel C. Carney, DVM, MS, DABVP,
# Theresa DePorter, DVM, MRCVS, DACVB, DECAWBM, Paula Plummer, LVT, VTS (ECC, SAIM), Jodi Westropp,
# DVM, PhD, DACVIM
# ABSTRACT
# The guidelines, authored by a Task Force ofexperts in feline clinical medicine, are an update and extension of the AAFP–AAHA
# Feline Life Stage Guidelines published in 2010. The guidelines are published simultaneously in theJournal of Feline Medicine and
# Surgery(volume 23, issue 3, pages 211–233, DOI: 10.1177/1098612X21993657) and theJournal of the American Animal Hospital
# Association(volume 57, issue 2, pages 51–72, DOI: 10.5326/JAAHA-MS-7189). A
#
# Metadata: {'producer': 'Acrobat Distiller 10.0.0 (Windows)', 'creator': 'Adobe InDesign CS6 (Windows)', 'creationdate': '2021-02-02T08:52:15-05:00', 'author': '7123', 'moddate': '2021-02-02T07:53:51-07:00', 'title': 'djs_jaaha_56_5_COVER.indd', 'source': 'cat_health_guidelines.pdf', 'total_pages': 22, 'page': 0, 'page_label': '1', 'document_type': 'cat_health_guideline', 'start_index': 0}

# %% [markdown]
# #### ❓Question #2
#
# What tradeoff do we make when choosing chunk size and chunk overlap?
#
# ##### ✅ Answer:
#
# Smaller chunks will smaller context window for LLM to process which could be helpful in a=inhanced accuracy. But it might come at the cost of lost contxt as some opart of the context could fall into another chunk.
#
# Large chunk overlap will ensure that context are not lost across chunk boundaries. But it might also include out of context or irrelevant data which might impact the correctness of retrieval.
#
# Use the [Chunk Visualizer](https://chunkviz.up.railway.app/) to experiment with different chunk sizes and overlaps and see how the text boundaries change.

# %% [markdown]
# ## Task 5: Embeddings and Qdrant
#
# Now we apply the same embedding idea to every chunk from the PDF. Qdrant stores those vectors and lets us search for chunks that are close to a query in embedding space.
#
# We already created an OpenAI embedding model in the primer above. The Qdrant collection name is just a label for the set of vectors we are creating.
#
# For this notebook, Qdrant runs in memory with `location=":memory:"`. That means no Docker, no Qdrant Cloud account, and no persistence after the notebook kernel stops.

# %%
collection_name = "cat_health_guidelines"

vector_store = QdrantVectorStore.from_documents(
    documents=splits,
    embedding=embeddings,
    location=":memory:",
    collection_name=collection_name,
    force_recreate=True,
)

print(f"Embedded chunks with: {embedding_model}")
print(f"Built in-memory Qdrant collection: {collection_name}")
# Out:
# Embedded chunks with: text-embedding-3-small
# Built in-memory Qdrant collection: cat_health_guidelines

# %% [markdown]
# ## Task 6: Retrieval with Scores
#
# Before we generate answers, we should inspect retrieval directly. If retrieval returns poor context, the final answer will usually be poor too.
#
# The value `k` controls how many chunks the retriever returns. A larger `k` gives the model more context, but it can also add noise. We will start with `k = 4` and tune it later.
#
# Qdrant can return both the matching `Document` and a similarity score. This is the same ranking idea we saw with `king`, `queen`, and `cat`, now applied to PDF chunks.

# %%
def display_retrieval_results(query: str, k: int) -> list[tuple]:
    """Retrieve chunks and print a compact view of the results."""
    results = vector_store.similarity_search_with_score(query, k=k)

    for index, (doc, score) in enumerate(results, start=1):
        page = doc.metadata.get("page")
        page_display = page + 1 if isinstance(page, int) else "unknown"
        start_index = doc.metadata.get("start_index", "unknown")
        preview = doc.page_content[:350].replace("\n", " ")

        print(f"Source {index} | score={score:.3f} | page={page_display} | start_index={start_index}")
        print(preview)
        print("-" * 80)

    return results

# %%
retrieval_k = 4
retrieval_query = "What signs suggest that a cat should be seen by a veterinarian?"
retrieved_results = display_retrieval_results(retrieval_query, k=retrieval_k)
# Out:
# Source 1 | score=0.584 | page=8 | start_index=0
# Detecting signs of pain or anxiety and evaluation of quality of life are most commonly of concern in the mature adult or senior cat but may be relevant at any life stage. During the physical examination, particular focus is on pain assessment and abdominal and thyroid palpation. A detailed mus- culoskeletal examination to detect signs of osteoarthr
# --------------------------------------------------------------------------------
# Source 2 | score=0.571 | page=7 | start_index=2384
# Asking speci ﬁc questions concerning whether vomiting, vom- iting hairballs, or diarrhea is occurring, and the frequency of each, is recommended as some clients may consider vomiting or vomiting hairballs to be normal for their cat. Additionally, discuss the im- portance of monitoring weight, and ask about any chronic enter- opathy or gastrointesti
# --------------------------------------------------------------------------------
# Source 3 | score=0.565 | page=7 | start_index=3237
# increased nocturnal activity and vocalization as well as changes in the cat ’s normal habits or activity. These may indicate cognitive dysfunction, disease-reduced mobility, pain, or reduced vision. TABLE 3 Diseases and Conditions That Require Particular Focus During Examination, by Life Stage 2021 AAHA/AAFP Feline Life Stage Guidelines JAAHA.ORG 5
# --------------------------------------------------------------------------------
# Source 4 | score=0.554 | page=7 | start_index=820
# 24 Changes in demeanor, activity level, and behavior are additionally key to note and trend over time. Asking speci ﬁc questions as to whether the kitten is displaying any unwanted behaviors, counselling clients on normal kitten be- havior, and giving advice on positive methods to modify unwanted behavior are critical discussion points at this stag
# --------------------------------------------------------------------------------

# %% [markdown]
# #### ❓Question #3
#
# What does a similarity score help you understand, and what does it not prove by itself?
#
# ##### ✅ Answer:
#
# Similarity score is telling me how similar are the vector embeddings for the query and the retrived document chunk. In above query, 4 most simlar chunks to query have ben retrieved. source 1 whose score is 0.584 is more csemantically close to the query as scource 2 with score of 0.571

# %% [markdown]
# ## Task 7: Retrieval Augmented Generation
#
# Now we combine retrieval with generation. We will use a two-step RAG pattern:
#
# 1. Retrieve relevant chunks from Qdrant
# 2. Put those chunks into the prompt and ask the model to answer from the context
#
# This is intentionally simpler than an agent. We always retrieve before answering, which makes the vector retrieval mechanics easy to inspect.
#
# For generation, we will use `gpt-5.4-mini`.

# %%
chat_model = "gpt-5.4-mini"
llm = ChatOpenAI(model=chat_model)

RAG_SYSTEM_PROMPT = """You are a cat health guideline assistant in a vector RAG lesson.

Use only the provided context to answer the user's question.
If the context does not contain enough information, say: "I don't have enough information in the provided cat health guideline PDF to answer that."

Cite the retrieved sources inline using labels like [Source 1] or [Source 2].
Do not diagnose, prescribe medication, or replace a veterinarian.
For diagnosis, treatment decisions, medication questions, or urgent symptoms, recommend contacting a veterinarian.
Keep the answer concise and practical."""

RAG_USER_PROMPT = """Context:
{context}

Question: {question}

Answer from the context above."""

rag_prompt = ChatPromptTemplate.from_messages(
    [
        ("system", RAG_SYSTEM_PROMPT),
        ("human", RAG_USER_PROMPT),
    ]
)

rag_chain = rag_prompt | llm | StrOutputParser()

# %%
def format_context(scored_docs: list[tuple]) -> str:
    """Convert retrieved documents into a source-labeled context string."""
    formatted_chunks = []

    for index, (doc, score) in enumerate(scored_docs, start=1):
        page = doc.metadata.get("page")
        page_display = page + 1 if isinstance(page, int) else "unknown"
        source = doc.metadata.get("source", "unknown source")

        formatted_chunks.append(
            f"[Source {index}] {source}, page {page_display}, score {score:.3f}\n"
            f"{doc.page_content}"
        )

    return "\n\n".join(formatted_chunks)


def answer_question(question: str, k: int) -> dict:
    """Run retrieve-then-generate and return the answer plus source metadata."""
    scored_docs = vector_store.similarity_search_with_score(question, k=k)
    context = format_context(scored_docs)
    answer = rag_chain.invoke({"context": context, "question": question})

    sources = []
    for index, (doc, score) in enumerate(scored_docs, start=1):
        page = doc.metadata.get("page")
        sources.append(
            {
                "source_label": f"Source {index}",
                "file": doc.metadata.get("source"),
                "page": page + 1 if isinstance(page, int) else None,
                "start_index": doc.metadata.get("start_index"),
                "score": score,
            }
        )

    return {
        "question": question,
        "answer": answer,
        "sources": sources,
        "context": scored_docs,
    }

# %% [markdown]
# Before calling the model, inspect the formatted context. This is the exact text that will be inserted into the RAG prompt.

# %%
example_context = format_context(retrieved_results[:2])
print(example_context[:2000])
# Out:
# [Source 1] cat_health_guidelines.pdf, page 8, score 0.584
# Detecting signs of pain or anxiety and evaluation of quality of life
# are most commonly of concern in the mature adult or senior cat but
# may be relevant at any life stage.
# During the physical examination, particular focus is on pain
# assessment and abdominal and thyroid palpation. A detailed mus-
# culoskeletal examination to detect signs of osteoarthritis is critical as
# this condition is one of the most signi ﬁcant and underdiagnosed
# diseases in cats.
# 23,28 A fundic examination is key to detecting signs of
# ophthalmic disease or hypertension. 29 Practices should employ a
# validated pain assessment scale or tool to diagnose, monitor, and
# assist in the evaluation of patients for subtle signs of pain.
# 30
# Changes in grooming habits, particularly increased grooming,
# may signal a dermatologic issue such as atopy, food allergy, an
# immune-mediated skin condition, infectious or parasitic disease,
# endocrine condition, or paraneoplastic syndrome.
# 31 Reduced grooming
#
# [Source 2] cat_health_guidelines.pdf, page 7, score 0.571
# Asking speci ﬁc questions concerning whether vomiting, vom-
# iting hairballs, or diarrhea is occurring, and the frequency of each, is
# recommended as some clients may consider vomiting or vomiting
# hairballs to be normal for their cat. Additionally, discuss the im-
# portance of monitoring weight, and ask about any chronic enter-
# opathy or gastrointestinal (GI) signs that could indicate early stages of
# disease.
# Mature Adult and Senior Cats
# The medical history and examination of mature adult and senior cats
# will be focused on early detection of disease. Adult and senior cats are
# often diagnosed with comorbidities. Speci ﬁc questions regarding
# changes in appetite, occurrence of polyuria and polydipsia, vomiting,
# vomiting hairballs, or diarrhea are of key importance to guide di-
# agnostic testing. Discussion should also be held with the client about
# increased nocturnal activity and vocalization as well as changes

# %%
answer_k = 4

result = answer_question(
    "What are signs that my cat may need veterinary attention?",
    k=answer_k,
)

print(result["answer"])
print("\nSources:")
for source in result["sources"]:
    print(source)
# Out:
# Signs that may mean your cat needs veterinary attention include:
#
# - **Pain or anxiety signs**, especially in mature adult or senior cats, but they can occur at any age [Source 1]
# - **Changes in grooming**:
#   - **Increased grooming** can be linked to skin, allergy, parasitic, endocrine, or other conditions [Source 1]
#   - **Reduced grooming** may indicate underlying illness, bladder pain, degenerative joint disease pain, or reduced mobility [Source 2]
# - **Musculoskeletal problems**, including signs of **osteoarthritis** or reduced mobility [Source 1]
# - **Behavior changes** such as house-soiling or aggression [Source 2]
# - **Vomiting, vomiting hairballs, or diarrhea**, especially if frequent or new [Source 3]
# - **Changes in appetite**, **increased thirst/urination**, or **increased nocturnal activity and vocalization** [Source 3]
# - **Signs of fear or stress**, such as cowering, crouching, hiding, freezing, flat ears, dilated pupils, forward whiskers, or hissing/yowling/growling [Source 4]
#
# If you’re seeing any of these, it’s a good idea to **contact a veterinarian** for an evaluation.
#
# Sources:
# {'source_label': 'Source 1', 'file': 'cat_health_guidelines.pdf', 'page': 8, 'start_index': 0, 'score': 0.5964587610724571}
# {'source_label': 'Source 2', 'file': 'cat_health_guidelines.pdf', 'page': 8, 'start_index': 767, 'score': 0.5685754968310671}
# {'source_label': 'Source 3', 'file': 'cat_health_guidelines.pdf', 'page': 7, 'start_index': 2384, 'score': 0.5573897648606023}
# {'source_label': 'Source 4', 'file': 'cat_health_guidelines.pdf', 'page': 8, 'start_index': 3963, 'score': 0.5538010885208121}

# %% [markdown]
# ### Vibe Check Queries
#
# Run a few questions that should be answerable from a cat health guideline PDF. Then run one question that may not be answerable and confirm the assistant says it does not have enough information.

# %%
vibe_check_questions = [
    "What preventive care is recommended for cats?",
    "What symptoms should make me call a veterinarian?",
    "What should I know about feeding a healthy adult cat?",
    "Can my cat help me file my taxes?",
]

for question in vibe_check_questions:
    print("Question:", question)
    print(answer_question(question, k=answer_k)["answer"])
    print("=" * 100)
# Out:
# Question: What preventive care is recommended for cats?
# The guidelines recommend **individualized preventive care** based on a cat’s life stage, health status, and risk factors [Source 2][Source 4]. Key preventive care includes:
#
# - **At least annual veterinary examinations** for all cats, with more frequent visits as needed [Source 4]
# - **Senior cats:** exams at least every **6 months** [Source 4]
# - **Parasite prevention/control**, often using broad-spectrum products, especially if the cat has outdoor exposure or travels/boards [Source 1]
# - **Treating household pets in sync** if a newly acquired kitten or cat may carry infectious parasites [Source 1]
# - **Reducing exposure to contaminated environments** like gardens and children’s sand areas to lower parasite and zoonotic risk [Source 1]
#
# If you want, I can also summarize the preventive care points by life stage.
# ====================================================================================================
# Question: What symptoms should make me call a veterinarian?
# Based on the guideline, you should contact a veterinarian if your cat has any of these symptoms or changes: changes in appetite, increased urination or drinking (polyuria/polydipsia), vomiting, vomiting hairballs, diarrhea, weight loss or unexplained changes in weight, chronic GI/enteropathy signs, increased nocturnal activity or vocalization, or changes in normal habits/activity [Source 1]. In senior cats, reduced jumping or climbing can also be a concern because it may indicate pain, mobility issues, or other disease [Source 2].
#
# If the symptoms seem urgent or severe, contact a veterinarian promptly.
# ====================================================================================================
# Question: What should I know about feeding a healthy adult cat?
# For a healthy adult cat, feeding should be based on the cat’s life stage, body condition score (BCS), muscle condition score (MCS), activity level, reproductive status, and overall health [Source 2]. Young, healthy adults are typically fed using daily energy requirements (DER), which are calculated from resting energy requirements (RER) and multiplied by a needs factor of 1 [Source 1]. The guideline gives RER as: 30 × body weight in kg + 70 [Source 1].
#
# Key points:
# - Adjust the amount fed to maintain ideal body condition [Source 3].
# - Overweight cats are considered BCS 6/9 or 7/9; obese cats are 8/9 or higher [Source 3].
# - Cats should be fed diets labeled with an AAFCO statement of nutritional adequacy to help avoid nutrient deficiencies [Source 2].
# - The guideline does not recommend raw or dehydrated non-sterilized animal-origin foods [Source 2].
# - If changing diets, transition gradually over 7–10 days [Source 4].
#
# If you want, I can also help interpret the calorie formula using your cat’s weight.
# ====================================================================================================
# Question: Can my cat help me file my taxes?
# I don't have enough information in the provided cat health guideline PDF to answer that.
# ====================================================================================================

# %% [markdown]
# #### ❓Question #4
#
# For the vibe check queries above, did the retrieved context seem relevant before generation? Why or why not?
#
# ##### ✅ Answer:
#
# Yes retrieved context seem relevant before generation to help LLM genarate correct answers. For the query related to tax, contxt couldn't be retrieved hence llm returned with no answer.

# %% [markdown]
# ## 🏗️ Activity: Tune Retrieval Quality
#
# Improve retrieval quality by changing one or more of these values:
#
# - The chunk size
# - The chunk overlap
# - The retrieval `k`
# - The wording of the retrieval query
#
# Suggested workflow:
#
# 1. Pick one test question.
# 2. Inspect the retrieved chunks and scores.
# 3. Change one retrieval setting.
# 4. Rebuild the splitter and vector store.
# 5. Compare whether the retrieved chunks became more relevant.
#
# When you are done, write down what changed and whether the final answer improved.

# %%
# Activity workspace
# Try retrieval tuning here.

### YOUR CODE HERE
# exp_collection_name = "cat_health_guidelines"
# exp_chunk_size = 1500
# exp_chunk_overlap = 300

# Step 1: Experiment with 4 combinations of chunk size and chunk overlap (1000, 200), (500, 300), (500, 100), (1500, 300),(1500, 100)

# List of tuple with chunk size and chunk overlap
exp_chunk_size_overlap_combinations = [
    (1000, 200),
    (500, 300),
    (500, 100),
    (1500, 300),
    (1500, 100)
]

# Initialize list of text splitters
exp_text_splitters = []

# Iterate over combinations
for chunk_size, chunk_overlap in exp_chunk_size_overlap_combinations:
    exp_text_splitter = RecursiveCharacterTextSplitter(
        chunk_size=chunk_size,
        chunk_overlap=chunk_overlap,
        add_start_index=True,
    )
    current_splits=exp_text_splitter.split_documents(pages)
    exp_text_splitters.append((len(current_splits), current_splits))

for index, (num_splits, splits) in enumerate(exp_text_splitters):
    print(f"Split {len(pages)} pages into {num_splits} chunks.")

# Initialize dictionary of vector store with key as collection name and value as vector store
exp_vector_stores = {}

# Iterate over text splitters
for index, (num_splits, splits) in enumerate(exp_text_splitters):
    collection_name = f"cat_health_guidelines_{num_splits}"
    vector_store = QdrantVectorStore.from_documents(
        documents=splits,
        embedding=embeddings,
        location=":memory:",
        collection_name=collection_name,
        force_recreate=True,
    )
    print(f"Built in-memory Qdrant collection: {collection_name}")
    exp_vector_stores[collection_name] = vector_store

print(f"Embedded chunks with: {embedding_model}")

# print length of exp_vector_stores and all unique keys in exp_vector_stores
print(f"Length of exp_vector_stores: {len(exp_vector_stores)}")
print(f"Unique keys in exp_vector_stores: {len(set(exp_vector_stores.keys()))}")
# Out:
# Split 22 pages into 135 chunks.
# Split 22 pages into 500 chunks.
# Split 22 pages into 263 chunks.
# Split 22 pages into 91 chunks.
# Split 22 pages into 87 chunks.
# Built in-memory Qdrant collection: cat_health_guidelines_135
# Built in-memory Qdrant collection: cat_health_guidelines_500
# Built in-memory Qdrant collection: cat_health_guidelines_263
# Built in-memory Qdrant collection: cat_health_guidelines_91
# Built in-memory Qdrant collection: cat_health_guidelines_87
# Embedded chunks with: text-embedding-3-small
# Length of exp_vector_stores: 5
# Unique keys in exp_vector_stores: 5

# %%
def enhanced_display_retrieval_results(query: str, k: int, collection_name: str) -> list[tuple]:
    """Retrieve chunks and print a compact view of the results."""
    results = exp_vector_stores[collection_name].similarity_search_with_score(query, k=k)

    for index, (doc, score) in enumerate(results, start=1):
        page = doc.metadata.get("page")
        page_display = page + 1 if isinstance(page, int) else "unknown"
        start_index = doc.metadata.get("start_index", "unknown")
        preview = doc.page_content[:350].replace("\n", " ")

        print(f"Source {index} | collection_name={collection_name} | k={k} | score={score:.3f} | page={page_display} | start_index={start_index}")
        print(preview)
        print("-" * 80)

    return results

# %%
# Step 2: Experiment with 4 combinations of retrieval k (4, 8, 12, 16)  

# List of retrieval k values
exp_retrieval_ks = [4, 8, 12, 16]

retrieval_query = "What are signs that my cat may need veterinary attention?"


for collection_name in exp_vector_stores:
    print(f"Running experiment for collection name: {collection_name}")
    print("*" * 80)
    for k in exp_retrieval_ks:
        results = enhanced_display_retrieval_results(retrieval_query, k, collection_name)
        print(results)
        print("-" * 80)
# Out:
# Running experiment for collection name: cat_health_guidelines_135
# ********************************************************************************
# Source 1 | collection_name=cat_health_guidelines_135 | k=4 | score=0.596 | page=8 | start_index=0
# Detecting signs of pain or anxiety and evaluation of quality of life are most commonly of concern in the mature adult or senior cat but may be relevant at any life stage. During the physical examination, particular focus is on pain assessment and abdominal and thyroid palpation. A detailed mus- culoskeletal examination to detect signs of osteoarthr
# --------------------------------------------------------------------------------
# Source 2 | collection_name=cat_health_guidelines_135 | k=4 | score=0.569 | page=8 | start_index=767
# may signal a dermatologic issue such as atopy, food allergy, an immune-mediated skin condition, infectious or parasitic disease, endocrine condition, or paraneoplastic syndrome. 31 Reduced grooming by the cat may also indicate underlying illness, bladder pain, degener- ative joint disease (DJD) pain, or reduced mobility. Behavior and Environmental
# --------------------------------------------------------------------------------
# Source 3 | collection_name=cat_health_guidelines_135 | k=4 | score=0.557 | page=7 | start_index=2384
# Asking speci ﬁc questions concerning whether vomiting, vom- iting hairballs, or diarrhea is occurring, and the frequency of each, is recommended as some clients may consider vomiting or vomiting hairballs to be normal for their cat. Additionally, discuss the im- portance of monitoring weight, and ask about any chronic enter- opathy or gastrointesti
# --------------------------------------------------------------------------------
# Source 4 | collection_name=cat_health_guidelines_135 | k=4 | score=0.554 | page=8 | start_index=3963
# most subtle signs of anxiety and tension. Clinical signs of fear or stress in cats are displayed through characteristic body postures, vocalizations, and activity. A cowering (tense, ﬂattened) position where the head is lower than the body may be indicative of stress or fear in cats. A state of distress may also be characterized by crouching, crawl
# --------------------------------------------------------------------------------
# [(Document(metadata={'producer': 'Acrobat Distiller 10.0.0 (Windows)', 'creator': 'Adobe InDesign CS6 (Windows)', 'creationdate': '2021-02-02T08:52:15-05:00', 'author': '7123', 'moddate': '2021-02-02T07:53:51-07:00', 'title': 'djs_jaaha_56_5_COVER.indd', 'source': 'cat_health_guidelines.pdf', 'total_pages': 22, 'page': 7, 'page_label': '8', 'document_type': 'cat_health_guideline', 'start_index': 0, '_id': 'e661e73d382541788c9c0d6ced72f6f3', '_collection_name': 'cat_health_guidelines_135'}, page_content='Detecting signs of pain or anxiety and evaluation of quality of life\nare most commonly of concern in the mature adult or senior cat but\nmay be relevant at any life stage.\nDuring the physical examination, particular focus is on pain\nassessment and abdominal and thyroid palpation. A detailed mus-\nculoskeletal examination to detect signs of osteoarthritis is critical as\nthis condition is one of the most signi ﬁcant and underdiagnosed\ndiseases in cats.\n23,28 A fundic examination is key to detecting signs of\nophthalmic disease or hypertension. 29 Practices should employ a\nvalidated pain assessment scale or tool to diagnose, monitor, and\nassist in the evaluation of patients for subtle signs of pain.\n30\nChanges in grooming habits, particularly increased grooming,\nmay signal a dermatologic issue such as atopy, food allergy, an\nimmune-mediated skin condition, infectious or parasitic disease,\nendocrine condition, or paraneoplastic syndrome.\n31 Reduced grooming'), 0.5964587610724571), (Document(metadata={'producer': 'Acrobat Distiller 10.0.0 (Windows)', 'creator': 'Adobe InDesign CS6 (Windows)', 'creationdate': '2021-02-02T08:52:15-05:00', 'author': '7123', 'moddate': '2021-02-02T07:53:51-07:00', 'title': 'djs_jaaha_56_5_COVER.indd', 'source': 'cat_health_guidelines.pdf', 'total_pages': 22, 'page': 7, 'page_label': '8', 'document_type': 'cat_health_guideline', 'start_index': 767, '_id': '7e7c979aae52413b9e9d7ef89e10e4c1', '_collection_name': 'cat_health_guidelines_135'}, page_content='may signal a dermatologic issue such as atopy, food allergy, an\nimmune-mediated skin condition, infectious or parasitic disease,\nendocrine condition, or paraneoplastic syndrome.\n31 Reduced grooming\nby the cat may also indicate underlying illness, bladder pain, degener-\native joint disease (DJD) pain, or reduced mobility.\nBehavior and Environmental Needs\nUnderstanding and Enhancing Behavior by Life Stage\nFeline health and welfare are intricately interrelated at all life stages.\nFrom kitten to senior, an appreciation of the behavioral needs of the\ncat is essential for preventing behavior problems. Problem behaviors\nmay be manifestations of normal feline behaviors, ranging from\nundesirable to pathological misbehaviors. Such problems continue to\nbe a primary reason for relinquishment.\n32 House-soiling (marking or\ntoileting outside the litter box) 33 and aggression toward people,\nhousemate cats, or housemate dogs 34 are commonly reported rea-\nsons for relinquishment.'), 0.5685754968310671), (Document(metadata={'producer': 'Acrobat Distiller 10.0.0 (Windows)', 'creator': 'Adobe InDesign CS6 (Windows)', 'creationdate': '2021-02-02T08:52:15-05:00', 'author': '7123', 'moddate': '2021-02-02T07:53:51-07:00', 'title': 'djs_jaaha_56_5_COVER.indd', 'source': 'cat_health_guidelines.pdf', 'total_pages': 22, 'page': 6, 'page_label': '7', 'document_type': 'cat_health_guideline', 'start_index': 2384, '_id': '8015855ff7544b5e8d9d7c78df256a63', '_collection_name': 'cat_health_guidelines_135'}, page_content='Asking speci ﬁc questions concerning whether vomiting, vom-\niting hairballs, or diarrhea is occurring, and the frequency of each, is\nrecommended as some clients may consider vomiting or vomiting\nhairballs to be normal for their cat. Additionally, discuss the im-\nportance of monitoring weight, and ask about any chronic enter-\nopathy or gastrointestinal (GI) signs that could indicate early stages of\ndisease.\nMature Adult and Senior Cats\ ...
# --------------------------------------------------------------------------------
# Source 1 | collection_name=cat_health_guidelines_135 | k=8 | score=0.596 | page=8 | start_index=0
# Detecting signs of pain or anxiety and evaluation of quality of life are most commonly of concern in the mature adult or senior cat but may be relevant at any life stage. During the physical examination, particular focus is on pain assessment and abdominal and thyroid palpation. A detailed mus- culoskeletal examination to detect signs of osteoarthr
# --------------------------------------------------------------------------------
# Source 2 | collection_name=cat_health_guidelines_135 | k=8 | score=0.569 | page=8 | start_index=767
# may signal a dermatologic issue such as atopy, food allergy, an immune-mediated skin condition, infectious or parasitic disease, endocrine condition, or paraneoplastic syndrome. 31 Reduced grooming by the cat may also indicate underlying illness, bladder pain, degener- ative joint disease (DJD) pain, or reduced mobility. Behavior and Environmental
# --------------------------------------------------------------------------------
# Source 3 | collection_name=cat_health_guidelines_135 | k=8 | score=0.557 | page=7 | start_index=2384
# Asking speci ﬁc questions concerning whether vomiting, vom- iting hairballs, or diarrhea is occurring, and the frequency of each, is recommended as some clients may consider vomiting or vomiting hairballs to be normal for their cat. Additionally, discuss the im- portance of monitoring weight, and ask about any chronic enter- opathy or gastrointesti
# --------------------------------------------------------------------------------
# Source 4 | collection_name=cat_health_guidelines_135 | k=8 | score=0.554 | page=8 | start_index=3963
# most subtle signs of anxiety and tension. Clinical signs of fear or stress in cats are displayed through characteristic body postures, vocalizations, and activity. A cowering (tense, ﬂattened) position where the head is lower than the body may be indicative of stress or fear in cats. A state of distress may also be characterized by crouching, crawl
# --------------------------------------------------------------------------------
# Source 5 | collection_name=cat_health_guidelines_135 | k=8 | score=0.553 | page=7 | start_index=3237
# increased nocturnal activity and vocalization as well as changes in the cat ’s normal habits or activity. These may indicate cognitive dysfunction, disease-reduced mobility, pain, or reduced vision. TABLE 3 Diseases and Conditions That Require Particular Focus During Examination, by Life Stage 2021 AAHA/AAFP Feline Life Stage Guidelines JAAHA.ORG 5
# --------------------------------------------------------------------------------
# Source 6 | collection_name=cat_health_guidelines_135 | k=8 | score=0.538 | page=10 | start_index=1637
# Young Adult Cats Y oung adult cats do not require as frequent routine medical care as kittens, so it is integral to educate the client about why regular healthcare examinations remain so important. Routine examinations can help identify behavioral changes or medical concerns that may affect a cat ’s health long before they become signi ﬁcant, painf
# --------------------------------------------------------------------------------
# Source 7 | collection_name=cat_health_guidelines_135 | k=8 | score=0.530 | page=10 | start_index=4793
# dysfunction syndrome, pain, hyper thyroidism, or hypertension. V et- erinary visits may be more challenging for the senior cat, in part be- cause many cat owners do not seek wellness visits, but present their cats only for acute care. 3 The use of pheromones or pre–veterinary visit pharmaceuticals such as gabapentin or trazodone may reduce stress w
# --------------------------------------------------------------------------------
# Source 8 | collection_name=cat_health_guidelines_135 | k=8 | score=0.530 | page=7 | start_index=820
# 24 Changes in demeanor, activity level, and behavior are additionally key to note and trend over time. Asking speci ﬁc questions as to whether the kitten is displaying any unwanted behaviors, counselling clients on normal kitten be- havior, and giving advice on positive methods to modify unwanted behavior are critical discussion points at this stag
# --------------------------------------------------------------------------------
# [(Document(metadata={'producer': 'Acrobat Distiller 10.0.0 (Windows)', 'creator': 'Adobe InDesign CS6 (Windows)', 'creationdate': '2021-02-02T08:52:15-05:00', 'author': '7123', 'moddate': '2021-02-02T07:53:51-07:00', 'title': 'djs_jaaha_56_5_COVER.indd', 'source': 'cat_health_guidelines.pdf', 'total_pages': 22, 'page': 7, 'page_label': '8', 'document_type': 'cat_health_guideline', 'start_index': 0, '_id': 'e661e73d382541788c9c0d6ced72f6f3', '_collection_name': 'cat_health_guidelines_135'}, page_content='Detecting signs of pain or anxiety and evaluation of quality of life\nare most commonly of concern in the mature adult or senior cat but\nmay be relevant at any life stage.\nDuring the physical examination, particular focus is on pain\nassessment and abdominal and thyroid palpation. A detailed mus-\nculoskeletal examination to detect signs of osteoarthritis is critical as\nthis condition is one of the most signi ﬁcant and underdiagnosed\ndiseases in cats.\n23,28 A fundic examination is key to detecting signs of\nophthalmic disease or hypertension. 29 Practices should employ a\nvalidated pain assessment scale or tool to diagnose, monitor, and\nassist in the evaluation of patients for subtle signs of pain.\n30\nChanges in grooming habits, particularly increased grooming,\nmay signal a dermatologic issue such as atopy, food allergy, an\nimmune-mediated skin condition, infectious or parasitic disease,\nendocrine condition, or paraneoplastic syndrome.\n31 Reduced grooming'), 0.5964587610724571), (Document(metadata={'producer': 'Acrobat Distiller 10.0.0 (Windows)', 'creator': 'Adobe InDesign CS6 (Windows)', 'creationdate': '2021-02-02T08:52:15-05:00', 'author': '7123', 'moddate': '2021-02-02T07:53:51-07:00', 'title': 'djs_jaaha_56_5_COVER.indd', 'source': 'cat_health_guidelines.pdf', 'total_pages': 22, 'page': 7, 'page_label': '8', 'document_type': 'cat_health_guideline', 'start_index': 767, '_id': '7e7c979aae52413b9e9d7ef89e10e4c1', '_collection_name': 'cat_health_guidelines_135'}, page_content='may signal a dermatologic issue such as atopy, food allergy, an\nimmune-mediated skin condition, infectious or parasitic disease,\nendocrine condition, or paraneoplastic syndrome.\n31 Reduced grooming\nby the cat may also indicate underlying illness, bladder pain, degener-\native joint disease (DJD) pain, or reduced mobility.\nBehavior and Environmental Needs\nUnderstanding and Enhancing Behavior by Life Stage\nFeline health and welfare are intricately interrelated at all life stages.\nFrom kitten to senior, an appreciation of the behavioral needs of the\ncat is essential for preventing behavior problems. Problem behaviors\nmay be manifestations of normal feline behaviors, ranging from\nundesirable to pathological misbehaviors. Such problems continue to\nbe a primary reason for relinquishment.\n32 House-soiling (marking or\ntoileting outside the litter box) 33 and aggression toward people,\nhousemate cats, or housemate dogs 34 are commonly reported rea-\nsons for relinquishment.'), 0.5685754968310671), (Document(metadata={'producer': 'Acrobat Distiller 10.0.0 (Windows)', 'creator': 'Adobe InDesign CS6 (Windows)', 'creationdate': '2021-02-02T08:52:15-05:00', 'author': '7123', 'moddate': '2021-02-02T07:53:51-07:00', 'title': 'djs_jaaha_56_5_COVER.indd', 'source': 'cat_health_guidelines.pdf', 'total_pages': 22, 'page': 6, 'page_label': '7', 'document_type': 'cat_health_guideline', 'start_index': 2384, '_id': '8015855ff7544b5e8d9d7c78df256a63', '_collection_name': 'cat_health_guidelines_135'}, page_content='Asking speci ﬁc questions concerning whether vomiting, vom-\niting hairballs, or diarrhea is occurring, and the frequency of each, is\nrecommended as some clients may consider vomiting or vomiting\nhairballs to be normal for their cat. Additionally, discuss the im-\nportance of monitoring weight, and ask about any chronic enter-\nopathy or gastrointestinal (GI) signs that could indicate early stages of\ndisease.\nMature Adult and Senior Cats\ ...
# --------------------------------------------------------------------------------
# Source 1 | collection_name=cat_health_guidelines_135 | k=12 | score=0.596 | page=8 | start_index=0
# Detecting signs of pain or anxiety and evaluation of quality of life are most commonly of concern in the mature adult or senior cat but may be relevant at any life stage. During the physical examination, particular focus is on pain assessment and abdominal and thyroid palpation. A detailed mus- culoskeletal examination to detect signs of osteoarthr
# --------------------------------------------------------------------------------
# Source 2 | collection_name=cat_health_guidelines_135 | k=12 | score=0.569 | page=8 | start_index=767
# may signal a dermatologic issue such as atopy, food allergy, an immune-mediated skin condition, infectious or parasitic disease, endocrine condition, or paraneoplastic syndrome. 31 Reduced grooming by the cat may also indicate underlying illness, bladder pain, degener- ative joint disease (DJD) pain, or reduced mobility. Behavior and Environmental
# --------------------------------------------------------------------------------
# Source 3 | collection_name=cat_health_guidelines_135 | k=12 | score=0.557 | page=7 | start_index=2384
# Asking speci ﬁc questions concerning whether vomiting, vom- iting hairballs, or diarrhea is occurring, and the frequency of each, is recommended as some clients may consider vomiting or vomiting hairballs to be normal for their cat. Additionally, discuss the im- portance of monitoring weight, and ask about any chronic enter- opathy or gastrointesti
# --------------------------------------------------------------------------------
# Source 4 | collection_name=cat_health_guidelines_135 | k=12 | score=0.554 | page=8 | start_index=3963
# most subtle signs of anxiety and tension. Clinical signs of fear or stress in cats are displayed through characteristic body postures, vocalizations, and activity. A cowering (tense, ﬂattened) position where the head is lower than the body may be indicative of stress or fear in cats. A state of distress may also be characterized by crouching, crawl
# --------------------------------------------------------------------------------
# Source 5 | collection_name=cat_health_guidelines_135 | k=12 | score=0.553 | page=7 | start_index=3237
# increased nocturnal activity and vocalization as well as changes in the cat ’s normal habits or activity. These may indicate cognitive dysfunction, disease-reduced mobility, pain, or reduced vision. TABLE 3 Diseases and Conditions That Require Particular Focus During Examination, by Life Stage 2021 AAHA/AAFP Feline Life Stage Guidelines JAAHA.ORG 5
# --------------------------------------------------------------------------------
# Source 6 | collection_name=cat_health_guidelines_135 | k=12 | score=0.538 | page=10 | start_index=1637
# Young Adult Cats Y oung adult cats do not require as frequent routine medical care as kittens, so it is integral to educate the client about why regular healthcare examinations remain so important. Routine examinations can help identify behavioral changes or medical concerns that may affect a cat ’s health long before they become signi ﬁcant, painf
# --------------------------------------------------------------------------------
# Source 7 | collection_name=cat_health_guidelines_135 | k=12 | score=0.530 | page=10 | start_index=4793
# dysfunction syndrome, pain, hyper thyroidism, or hypertension. V et- erinary visits may be more challenging for the senior cat, in part be- cause many cat owners do not seek wellness visits, but present their cats only for acute care. 3 The use of pheromones or pre–veterinary visit pharmaceuticals such as gabapentin or trazodone may reduce stress w
# --------------------------------------------------------------------------------
# Source 8 | collection_name=cat_health_guidelines_135 | k=12 | score=0.530 | page=7 | start_index=820
# 24 Changes in demeanor, activity level, and behavior are additionally key to note and trend over time. Asking speci ﬁc questions as to whether the kitten is displaying any unwanted behaviors, counselling clients on normal kitten be- havior, and giving advice on positive methods to modify unwanted behavior are critical discussion points at this stag
# --------------------------------------------------------------------------------
# Source 9 | collection_name=cat_health_guidelines_135 | k=12 | score=0.527 | page=10 | start_index=3964
# 60–65 The focus should be on providing an appropriate, stimulating, and safe environment for the cat. 38 All cats should be microchipped for permanent identi ﬁcation. Play Declining play activity increases susceptibility to weight gain. In one study, three 10- to 15-minute exercise sessions per day led to a loss of approximately 1% of body weight i
# --------------------------------------------------------------------------------
# Source 10 | collection_name=cat_health_guidelines_135 | k=12 | score=0.519 | page=8 | start_index=4719
# with them curled into the body in a typical relaxed pose). V ocalizations, including hissing, yowling, growling, or screaming, may indicate defensiveness. A rapid respiratory rate not associated with disease or exertion may also be observed. The tail may ﬂip or twitch as the cat becomes agitated; the rate and intensity of the tail movement correlat
# --------------------------------------------------------------------------------
# Source 11 | collection_name=cat_health_guidelines_135 | k=12 | score=0.519 | page=7 | start_index=0
# detection of changes and identi ﬁcation of trends. 20 Obtaining dorsal and lateral photographs of the patient is recommended to facilitate monitoring BCS/MCS as the cat ages, and can help the owner recognize subtle changes. Diseases and conditions that require additional focus during the examination by each life stage are listed in Table 3. Kittens
# --------------------------------------------------------------------------------
# Source 12 | collection_name=cat_health_guidelines_135 | k=12 | score=0.514 | page=2 | start_index=821
# alized risk assessment, preventive healthcare strategies, and treat- ment pathways that evolve as the cat matures. An evidence-guided framework for managing a cat ’s healthcare throughout its lifetime has never been more important in feline practice than it is now. Cats are the most popular pet in the United States. 1 A great anomaly in feline prac
# --------------------------------------------------------------------------------
# [(Document(metadata={'producer': 'Acrobat Distiller 10.0.0 (Windows)', 'creator': 'Adobe InDesign CS6 (Windows)', 'creationdate': '2021-02-02T08:52:15-05:00', 'author': '7123', 'moddate': '2021-02-02T07:53:51-07:00', 'title': 'djs_jaaha_56_5_COVER.indd', 'source': 'cat_health_guidelines.pdf', 'total_pages': 22, 'page': 7, 'page_label': '8', 'document_type': 'cat_health_guideline', 'start_index': 0, '_id': 'e661e73d382541788c9c0d6ced72f6f3', '_collection_name': 'cat_health_guidelines_135'}, page_content='Detecting signs of pain or anxiety and evaluation of quality of life\nare most commonly of concern in the mature adult or senior cat but\nmay be relevant at any life stage.\nDuring the physical examination, particular focus is on pain\nassessment and abdominal and thyroid palpation. A detailed mus-\nculoskeletal examination to detect signs of osteoarthritis is critical as\nthis condition is one of the most signi ﬁcant and underdiagnosed\ndiseases in cats.\n23,28 A fundic examination is key to detecting signs of\nophthalmic disease or hypertension. 29 Practices should employ a\nvalidated pain assessment scale or tool to diagnose, monitor, and\nassist in the evaluation of patients for subtle signs of pain.\n30\nChanges in grooming habits, particularly increased grooming,\nmay signal a dermatologic issue such as atopy, food allergy, an\nimmune-mediated skin condition, infectious or parasitic disease,\nendocrine condition, or paraneoplastic syndrome.\n31 Reduced grooming'), 0.5964587610724571), (Document(metadata={'producer': 'Acrobat Distiller 10.0.0 (Windows)', 'creator': 'Adobe InDesign CS6 (Windows)', 'creationdate': '2021-02-02T08:52:15-05:00', 'author': '7123', 'moddate': '2021-02-02T07:53:51-07:00', 'title': 'djs_jaaha_56_5_COVER.indd', 'source': 'cat_health_guidelines.pdf', 'total_pages': 22, 'page': 7, 'page_label': '8', 'document_type': 'cat_health_guideline', 'start_index': 767, '_id': '7e7c979aae52413b9e9d7ef89e10e4c1', '_collection_name': 'cat_health_guidelines_135'}, page_content='may signal a dermatologic issue such as atopy, food allergy, an\nimmune-mediated skin condition, infectious or parasitic disease,\nendocrine condition, or paraneoplastic syndrome.\n31 Reduced grooming\nby the cat may also indicate underlying illness, bladder pain, degener-\native joint disease (DJD) pain, or reduced mobility.\nBehavior and Environmental Needs\nUnderstanding and Enhancing Behavior by Life Stage\nFeline health and welfare are intricately interrelated at all life stages.\nFrom kitten to senior, an appreciation of the behavioral needs of the\ncat is essential for preventing behavior problems. Problem behaviors\nmay be manifestations of normal feline behaviors, ranging from\nundesirable to pathological misbehaviors. Such problems continue to\nbe a primary reason for relinquishment.\n32 House-soiling (marking or\ntoileting outside the litter box) 33 and aggression toward people,\nhousemate cats, or housemate dogs 34 are commonly reported rea-\nsons for relinquishment.'), 0.5685754968310671), (Document(metadata={'producer': 'Acrobat Distiller 10.0.0 (Windows)', 'creator': 'Adobe InDesign CS6 (Windows)', 'creationdate': '2021-02-02T08:52:15-05:00', 'author': '7123', 'moddate': '2021-02-02T07:53:51-07:00', 'title': 'djs_jaaha_56_5_COVER.indd', 'source': 'cat_health_guidelines.pdf', 'total_pages': 22, 'page': 6, 'page_label': '7', 'document_type': 'cat_health_guideline', 'start_index': 2384, '_id': '8015855ff7544b5e8d9d7c78df256a63', '_collection_name': 'cat_health_guidelines_135'}, page_content='Asking speci ﬁc questions concerning whether vomiting, vom-\niting hairballs, or diarrhea is occurring, and the frequency of each, is\nrecommended as some clients may consider vomiting or vomiting\nhairballs to be normal for their cat. Additionally, discuss the im-\nportance of monitoring weight, and ask about any chronic enter-\nopathy or gastrointestinal (GI) signs that could indicate early stages of\ndisease.\nMature Adult and Senior Cats\ ...
# --------------------------------------------------------------------------------
# Source 1 | collection_name=cat_health_guidelines_135 | k=16 | score=0.596 | page=8 | start_index=0
# Detecting signs of pain or anxiety and evaluation of quality of life are most commonly of concern in the mature adult or senior cat but may be relevant at any life stage. During the physical examination, particular focus is on pain assessment and abdominal and thyroid palpation. A detailed mus- culoskeletal examination to detect signs of osteoarthr
# --------------------------------------------------------------------------------
# Source 2 | collection_name=cat_health_guidelines_135 | k=16 | score=0.569 | page=8 | start_index=767
# may signal a dermatologic issue such as atopy, food allergy, an immune-mediated skin condition, infectious or parasitic disease, endocrine condition, or paraneoplastic syndrome. 31 Reduced grooming by the cat may also indicate underlying illness, bladder pain, degener- ative joint disease (DJD) pain, or reduced mobility. Behavior and Environmental
# --------------------------------------------------------------------------------
# Source 3 | collection_name=cat_health_guidelines_135 | k=16 | score=0.557 | page=7 | start_index=2384
# Asking speci ﬁc questions concerning whether vomiting, vom- iting hairballs, or diarrhea is occurring, and the frequency of each, is recommended as some clients may consider vomiting or vomiting hairballs to be normal for their cat. Additionally, discuss the im- portance of monitoring weight, and ask about any chronic enter- opathy or gastrointesti
# --------------------------------------------------------------------------------
# Source 4 | collection_name=cat_health_guidelines_135 | k=16 | score=0.554 | page=8 | start_index=3963
# most subtle signs of anxiety and tension. Clinical signs of fear or stress in cats are displayed through characteristic body postures, vocalizations, and activity. A cowering (tense, ﬂattened) position where the head is lower than the body may be indicative of stress or fear in cats. A state of distress may also be characterized by crouching, crawl
# --------------------------------------------------------------------------------
# Source 5 | collection_name=cat_health_guidelines_135 | k=16 | score=0.553 | page=7 | start_index=3237
# increased nocturnal activity and vocalization as well as changes in the cat ’s normal habits or activity. These may indicate cognitive dysfunction, disease-reduced mobility, pain, or reduced vision. TABLE 3 Diseases and Conditions That Require Particular Focus During Examination, by Life Stage 2021 AAHA/AAFP Feline Life Stage Guidelines JAAHA.ORG 5
# --------------------------------------------------------------------------------
# Source 6 | collection_name=cat_health_guidelines_135 | k=16 | score=0.538 | page=10 | start_index=1637
# Young Adult Cats Y oung adult cats do not require as frequent routine medical care as kittens, so it is integral to educate the client about why regular healthcare examinations remain so important. Routine examinations can help identify behavioral changes or medical concerns that may affect a cat ’s health long before they become signi ﬁcant, painf
# --------------------------------------------------------------------------------
# Source 7 | collection_name=cat_health_guidelines_135 | k=16 | score=0.530 | page=10 | start_index=4793
# dysfunction syndrome, pain, hyper thyroidism, or hypertension. V et- erinary visits may be more challenging for the senior cat, in part be- cause many cat owners do not seek wellness visits, but present their cats only for acute care. 3 The use of pheromones or pre–veterinary visit pharmaceuticals such as gabapentin or trazodone may reduce stress w
# --------------------------------------------------------------------------------
# Source 8 | collection_name=cat_health_guidelines_135 | k=16 | score=0.530 | page=7 | start_index=820
# 24 Changes in demeanor, activity level, and behavior are additionally key to note and trend over time. Asking speci ﬁc questions as to whether the kitten is displaying any unwanted behaviors, counselling clients on normal kitten be- havior, and giving advice on positive methods to modify unwanted behavior are critical discussion points at this stag
# --------------------------------------------------------------------------------
# Source 9 | collection_name=cat_health_guidelines_135 | k=16 | score=0.527 | page=10 | start_index=3964
# 60–65 The focus should be on providing an appropriate, stimulating, and safe environment for the cat. 38 All cats should be microchipped for permanent identi ﬁcation. Play Declining play activity increases susceptibility to weight gain. In one study, three 10- to 15-minute exercise sessions per day led to a loss of approximately 1% of body weight i
# --------------------------------------------------------------------------------
# Source 10 | collection_name=cat_health_guidelines_135 | k=16 | score=0.519 | page=8 | start_index=4719
# with them curled into the body in a typical relaxed pose). V ocalizations, including hissing, yowling, growling, or screaming, may indicate defensiveness. A rapid respiratory rate not associated with disease or exertion may also be observed. The tail may ﬂip or twitch as the cat becomes agitated; the rate and intensity of the tail movement correlat
# --------------------------------------------------------------------------------
# Source 11 | collection_name=cat_health_guidelines_135 | k=16 | score=0.519 | page=7 | start_index=0
# detection of changes and identi ﬁcation of trends. 20 Obtaining dorsal and lateral photographs of the patient is recommended to facilitate monitoring BCS/MCS as the cat ages, and can help the owner recognize subtle changes. Diseases and conditions that require additional focus during the examination by each life stage are listed in Table 3. Kittens
# --------------------------------------------------------------------------------
# Source 12 | collection_name=cat_health_guidelines_135 | k=16 | score=0.514 | page=2 | start_index=821
# alized risk assessment, preventive healthcare strategies, and treat- ment pathways that evolve as the cat matures. An evidence-guided framework for managing a cat ’s healthcare throughout its lifetime has never been more important in feline practice than it is now. Cats are the most popular pet in the United States. 1 A great anomaly in feline prac
# --------------------------------------------------------------------------------
# Source 13 | collection_name=cat_health_guidelines_135 | k=16 | score=0.512 | page=6 | start_index=1613
# consultation. Discussions regarding anticipated costs of care and presentation of pet insurance options can help clients to plan ahead for future care needs. In some cases, estate planning may be appropriate to discuss. Many other topics will be revisited and modi ﬁed during subsequent examinations, including preventive healthcare and nutritional r
# --------------------------------------------------------------------------------
# Source 14 | collection_name=cat_health_guidelines_135 | k=16 | score=0.511 | page=11 | start_index=812
# critical to listen carefully to descriptions of changes in behavior, even seemingly positive changes. Senior cats may have reduced muscle mass or orthopedic conditions such that they would beneﬁtf r o mc o m f o r t a b l e and warm resting locations. It is also bene ﬁcial to increase resource a v a i l a b i l i t yt or e d u c et h ed i s t a n c
# --------------------------------------------------------------------------------
# Source 15 | collection_name=cat_health_guidelines_135 | k=16 | score=0.510 | page=14 | start_index=3203
# habits, a predilection the practitioner or owner can evaluate. Water- related factors to consider include freshness, taste, movement (e.g., provided by water fountains, dripping faucets, or aquarium pump – bubbled air into a bowl), and shape of container (some cats seem to resent having their vibrissae touch the sides of the container when drinking
# --------------------------------------------------------------------------------
# Source 16 | collection_name=cat_health_guidelines_135 | k=16 | score=0.509 | page=19 | start_index=3249
# free-roaming cats. Top Companion Anim Med 2017;32:91–5. 22. Whyte A, Lacasta S, Whyte J, et al. T ooth resorption in Spanish do- mestic cats: preliminary data. Top Companion Anim Med 2020;38: 100369. DOI: 10.1016/j.tcam.2019.100369. 23. Bennett D, Arifﬁn SMZ, Johnston P . Osteoarthritis in the cat: how common is it and how easy to recognise? J Feli
# --------------------------------------------------------------------------------
# [(Document(metadata={'producer': 'Acrobat Distiller 10.0.0 (Windows)', 'creator': 'Adobe InDesign CS6 (Windows)', 'creationdate': '2021-02-02T08:52:15-05:00', 'author': '7123', 'moddate': '2021-02-02T07:53:51-07:00', 'title': 'djs_jaaha_56_5_COVER.indd', 'source': 'cat_health_guidelines.pdf', 'total_pages': 22, 'page': 7, 'page_label': '8', 'document_type': 'cat_health_guideline', 'start_index': 0, '_id': 'e661e73d382541788c9c0d6ced72f6f3', '_collection_name': 'cat_health_guidelines_135'}, page_content='Detecting signs of pain or anxiety and evaluation of quality of life\nare most commonly of concern in the mature adult or senior cat but\nmay be relevant at any life stage.\nDuring the physical examination, particular focus is on pain\nassessment and abdominal and thyroid palpation. A detailed mus-\nculoskeletal examination to detect signs of osteoarthritis is critical as\nthis condition is one of the most signi ﬁcant and underdiagnosed\ndiseases in cats.\n23,28 A fundic examination is key to detecting signs of\nophthalmic disease or hypertension. 29 Practices should employ a\nvalidated pain assessment scale or tool to diagnose, monitor, and\nassist in the evaluation of patients for subtle signs of pain.\n30\nChanges in grooming habits, particularly increased grooming,\nmay signal a dermatologic issue such as atopy, food allergy, an\nimmune-mediated skin condition, infectious or parasitic disease,\nendocrine condition, or paraneoplastic syndrome.\n31 Reduced grooming'), 0.5964587610724571), (Document(metadata={'producer': 'Acrobat Distiller 10.0.0 (Windows)', 'creator': 'Adobe InDesign CS6 (Windows)', 'creationdate': '2021-02-02T08:52:15-05:00', 'author': '7123', 'moddate': '2021-02-02T07:53:51-07:00', 'title': 'djs_jaaha_56_5_COVER.indd', 'source': 'cat_health_guidelines.pdf', 'total_pages': 22, 'page': 7, 'page_label': '8', 'document_type': 'cat_health_guideline', 'start_index': 767, '_id': '7e7c979aae52413b9e9d7ef89e10e4c1', '_collection_name': 'cat_health_guidelines_135'}, page_content='may signal a dermatologic issue such as atopy, food allergy, an\nimmune-mediated skin condition, infectious or parasitic disease,\nendocrine condition, or paraneoplastic syndrome.\n31 Reduced grooming\nby the cat may also indicate underlying illness, bladder pain, degener-\native joint disease (DJD) pain, or reduced mobility.\nBehavior and Environmental Needs\nUnderstanding and Enhancing Behavior by Life Stage\nFeline health and welfare are intricately interrelated at all life stages.\nFrom kitten to senior, an appreciation of the behavioral needs of the\ncat is essential for preventing behavior problems. Problem behaviors\nmay be manifestations of normal feline behaviors, ranging from\nundesirable to pathological misbehaviors. Such problems continue to\nbe a primary reason for relinquishment.\n32 House-soiling (marking or\ntoileting outside the litter box) 33 and aggression toward people,\nhousemate cats, or housemate dogs 34 are commonly reported rea-\nsons for relinquishment.'), 0.5685754968310671), (Document(metadata={'producer': 'Acrobat Distiller 10.0.0 (Windows)', 'creator': 'Adobe InDesign CS6 (Windows)', 'creationdate': '2021-02-02T08:52:15-05:00', 'author': '7123', 'moddate': '2021-02-02T07:53:51-07:00', 'title': 'djs_jaaha_56_5_COVER.indd', 'source': 'cat_health_guidelines.pdf', 'total_pages': 22, 'page': 6, 'page_label': '7', 'document_type': 'cat_health_guideline', 'start_index': 2384, '_id': '8015855ff7544b5e8d9d7c78df256a63', '_collection_name': 'cat_health_guidelines_135'}, page_content='Asking speci ﬁc questions concerning whether vomiting, vom-\niting hairballs, or diarrhea is occurring, and the frequency of each, is\nrecommended as some clients may consider vomiting or vomiting\nhairballs to be normal for their cat. Additionally, discuss the im-\nportance of monitoring weight, and ask about any chronic enter-\nopathy or gastrointestinal (GI) signs that could indicate early stages of\ndisease.\nMature Adult and Senior Cats\ ...
# --------------------------------------------------------------------------------
# Running experiment for collection name: cat_health_guidelines_500
# ********************************************************************************
# Source 1 | collection_name=cat_health_guidelines_500 | k=4 | score=0.596 | page=8 | start_index=767
# may signal a dermatologic issue such as atopy, food allergy, an immune-mediated skin condition, infectious or parasitic disease, endocrine condition, or paraneoplastic syndrome. 31 Reduced grooming by the cat may also indicate underlying illness, bladder pain, degener- ative joint disease (DJD) pain, or reduced mobility. Behavior and Environmental
# --------------------------------------------------------------------------------
# Source 2 | collection_name=cat_health_guidelines_500 | k=4 | score=0.575 | page=10 | start_index=1856
# can help identify behavioral changes or medical concerns that may affect a cat ’s health long before they become signi ﬁcant, painful, or more costly to treat. Clients should be educated about the subtle changes in behavior and day-to-day life of the cat that may possibly be signi ﬁcant. Encouraging owners to routinely record behaviors in a journal
# --------------------------------------------------------------------------------
# Source 3 | collection_name=cat_health_guidelines_500 | k=4 | score=0.553 | page=8 | start_index=0
# Detecting signs of pain or anxiety and evaluation of quality of life are most commonly of concern in the mature adult or senior cat but may be relevant at any life stage. During the physical examination, particular focus is on pain assessment and abdominal and thyroid palpation. A detailed mus- culoskeletal examination to detect signs of osteoarthr
# --------------------------------------------------------------------------------
# Source 4 | collection_name=cat_health_guidelines_500 | k=4 | score=0.539 | page=7 | start_index=2964
# often diagnosed with comorbidities. Speci ﬁc questions regarding changes in appetite, occurrence of polyuria and polydipsia, vomiting, vomiting hairballs, or diarrhea are of key importance to guide di- agnostic testing. Discussion should also be held with the client about increased nocturnal activity and vocalization as well as changes in the cat ’
# --------------------------------------------------------------------------------
# [(Document(metadata={'producer': 'Acrobat Distiller 10.0.0 (Windows)', 'creator': 'Adobe InDesign CS6 (Windows)', 'creationdate': '2021-02-02T08:52:15-05:00', 'author': '7123', 'moddate': '2021-02-02T07:53:51-07:00', 'title': 'djs_jaaha_56_5_COVER.indd', 'source': 'cat_health_guidelines.pdf', 'total_pages': 22, 'page': 7, 'page_label': '8', 'document_type': 'cat_health_guideline', 'start_index': 767, '_id': '95e07d7915694e84967eb3378f543442', '_collection_name': 'cat_health_guidelines_500'}, page_content='may signal a dermatologic issue such as atopy, food allergy, an\nimmune-mediated skin condition, infectious or parasitic disease,\nendocrine condition, or paraneoplastic syndrome.\n31 Reduced grooming\nby the cat may also indicate underlying illness, bladder pain, degener-\native joint disease (DJD) pain, or reduced mobility.\nBehavior and Environmental Needs\nUnderstanding and Enhancing Behavior by Life Stage\nFeline health and welfare are intricately interrelated at all life stages.'), 0.5959032957573506), (Document(metadata={'producer': 'Acrobat Distiller 10.0.0 (Windows)', 'creator': 'Adobe InDesign CS6 (Windows)', 'creationdate': '2021-02-02T08:52:15-05:00', 'author': '7123', 'moddate': '2021-02-02T07:53:51-07:00', 'title': 'djs_jaaha_56_5_COVER.indd', 'source': 'cat_health_guidelines.pdf', 'total_pages': 22, 'page': 9, 'page_label': '10', 'document_type': 'cat_health_guideline', 'start_index': 1856, '_id': '99f1e3f966554b789bb5165fae22a5d0', '_collection_name': 'cat_health_guidelines_500'}, page_content='can help identify behavioral changes or medical concerns that may\naffect a cat ’s health long before they become signi ﬁcant, painful, or\nmore costly to treat. Clients should be educated about the subtle\nchanges in behavior and day-to-day life of the cat that may possibly\nbe signi ﬁcant. Encouraging owners to routinely record behaviors in\na journal and/or with photos and video will provide a basis for\ndocumenting any such changes. Simply asking the client, “Is your'), 0.574934640959659), (Document(metadata={'producer': 'Acrobat Distiller 10.0.0 (Windows)', 'creator': 'Adobe InDesign CS6 (Windows)', 'creationdate': '2021-02-02T08:52:15-05:00', 'author': '7123', 'moddate': '2021-02-02T07:53:51-07:00', 'title': 'djs_jaaha_56_5_COVER.indd', 'source': 'cat_health_guidelines.pdf', 'total_pages': 22, 'page': 7, 'page_label': '8', 'document_type': 'cat_health_guideline', 'start_index': 0, '_id': '4707dd6e18d64e3bbf21740f7e35622d', '_collection_name': 'cat_health_guidelines_500'}, page_content='Detecting signs of pain or anxiety and evaluation of quality of life\nare most commonly of concern in the mature adult or senior cat but\nmay be relevant at any life stage.\nDuring the physical examination, particular focus is on pain\nassessment and abdominal and thyroid palpation. A detailed mus-\nculoskeletal examination to detect signs of osteoarthritis is critical as\nthis condition is one of the most signi ﬁcant and underdiagnosed\ndiseases in cats.'), 0.5533412224572473), (Document(metadata={'producer': 'Acrobat Distiller 10.0.0 (Windows)', 'creator': 'Adobe InDesign CS6 (Windows)', 'creationdate': '2021-02-02T08:52:15-05:00', 'author': '7123', 'moddate': '2021-02-02T07:53:51-07:00', 'title': 'djs_jaaha_56_5_COVER.indd', 'source': 'cat_health_guidelines.pdf', 'total_pages': 22, 'page': 6, 'page_label': '7', 'document_type': 'cat_health_guideline', 'start_index': 2964, '_id': '6b0d06e36df0469aab3a54832d3afc9f', '_collection_name': 'cat_health_guidelines_500'}, page_content='often diagnosed with comorbidities. Speci ﬁc questions regarding\nchanges in appetite, occurrence of polyuria and polydipsia, vomiting,\nvomiting hairballs, or diarrhea are of key importance to guide di-\nagnostic testing. Discussion should also be held with the client about\nincreased nocturnal activity and vocalization as well as changes in\nthe cat ’s normal habits or activity. These may indicate cognitive\ndysfunction, disease-reduced mobility, pain, or ...
# --------------------------------------------------------------------------------
# Source 1 | collection_name=cat_health_guidelines_500 | k=8 | score=0.596 | page=8 | start_index=767
# may signal a dermatologic issue such as atopy, food allergy, an immune-mediated skin condition, infectious or parasitic disease, endocrine condition, or paraneoplastic syndrome. 31 Reduced grooming by the cat may also indicate underlying illness, bladder pain, degener- ative joint disease (DJD) pain, or reduced mobility. Behavior and Environmental
# --------------------------------------------------------------------------------
# Source 2 | collection_name=cat_health_guidelines_500 | k=8 | score=0.575 | page=10 | start_index=1856
# can help identify behavioral changes or medical concerns that may affect a cat ’s health long before they become signi ﬁcant, painful, or more costly to treat. Clients should be educated about the subtle changes in behavior and day-to-day life of the cat that may possibly be signi ﬁcant. Encouraging owners to routinely record behaviors in a journal
# --------------------------------------------------------------------------------
# Source 3 | collection_name=cat_health_guidelines_500 | k=8 | score=0.553 | page=8 | start_index=0
# Detecting signs of pain or anxiety and evaluation of quality of life are most commonly of concern in the mature adult or senior cat but may be relevant at any life stage. During the physical examination, particular focus is on pain assessment and abdominal and thyroid palpation. A detailed mus- culoskeletal examination to detect signs of osteoarthr
# --------------------------------------------------------------------------------
# Source 4 | collection_name=cat_health_guidelines_500 | k=8 | score=0.539 | page=7 | start_index=2964
# often diagnosed with comorbidities. Speci ﬁc questions regarding changes in appetite, occurrence of polyuria and polydipsia, vomiting, vomiting hairballs, or diarrhea are of key importance to guide di- agnostic testing. Discussion should also be held with the client about increased nocturnal activity and vocalization as well as changes in the cat ’
# --------------------------------------------------------------------------------
# Source 5 | collection_name=cat_health_guidelines_500 | k=8 | score=0.537 | page=8 | start_index=965
# by the cat may also indicate underlying illness, bladder pain, degener- ative joint disease (DJD) pain, or reduced mobility. Behavior and Environmental Needs Understanding and Enhancing Behavior by Life Stage Feline health and welfare are intricately interrelated at all life stages. From kitten to senior, an appreciation of the behavioral needs of
# --------------------------------------------------------------------------------
# Source 6 | collection_name=cat_health_guidelines_500 | k=8 | score=0.534 | page=6 | start_index=2656
# examination and for obtaining diagnostic samples. Observing how the cat is reacting to the environment may give clues as to its state of arousal. If the cat is a new patient to the veterinarian, the client may know from previous experience what works well for their pet. For example, does the cat relax when handled in a towel? What is the cat’s favo
# --------------------------------------------------------------------------------
# Source 7 | collection_name=cat_health_guidelines_500 | k=8 | score=0.533 | page=8 | start_index=370
# this condition is one of the most signi ﬁcant and underdiagnosed diseases in cats. 23,28 A fundic examination is key to detecting signs of ophthalmic disease or hypertension. 29 Practices should employ a validated pain assessment scale or tool to diagnose, monitor, and assist in the evaluation of patients for subtle signs of pain. 30 Changes in gro
# --------------------------------------------------------------------------------
# ...
# --------------------------------------------------------------------------------
# Source 1 | collection_name=cat_health_guidelines_87 | k=16 | score=0.597 | page=8 | start_index=0
# Detecting signs of pain or anxiety and evaluation of quality of life are most commonly of concern in the mature adult or senior cat but may be relevant at any life stage. During the physical examination, particular focus is on pain assessment and abdominal and thyroid palpation. A detailed mus- culoskeletal examination to detect signs of osteoarthr
# --------------------------------------------------------------------------------
# Source 2 | collection_name=cat_health_guidelines_87 | k=16 | score=0.558 | page=7 | start_index=1395
# detection of congenital issues such as a heart murmur, hernia, or cleft palate. A detailed oral examination is performed to detect abnormalities of dentition. The use of fecal scoring charts is very helpful to ensure that the client can accurately identify stool consistency. 25,26 Young Adult Cats Lower airway disease is common in young adult cats.
# --------------------------------------------------------------------------------
# Source 3 | collection_name=cat_health_guidelines_87 | k=16 | score=0.557 | page=8 | start_index=4165
# where the head is lower than the body may be indicative of stress or fear in cats. A state of distress may also be characterized by crouching, crawling, and muscular tension; activity may range from either freezing or hiding to frantic ﬂeeing. The ears may be held ﬂat, rotated to the side or all the way back when the cat is aroused, agitated or str
# --------------------------------------------------------------------------------
# Source 4 | collection_name=cat_health_guidelines_87 | k=16 | score=0.538 | page=7 | start_index=2794
# Mature Adult and Senior Cats The medical history and examination of mature adult and senior cats will be focused on early detection of disease. Adult and senior cats are often diagnosed with comorbidities. Speci ﬁc questions regarding changes in appetite, occurrence of polyuria and polydipsia, vomiting, vomiting hairballs, or diarrhea are of key im
# --------------------------------------------------------------------------------
# Source 5 | collection_name=cat_health_guidelines_87 | k=16 | score=0.532 | page=6 | start_index=1408
# can be valuable to guide more speci ﬁc questions such as, “Has there been any urination or defecation outside the litter box? ” to ensure other relevant information is not missed or left to the end of the consultation. Discussions regarding anticipated costs of care and presentation of pet insurance options can help clients to plan ahead for future
# --------------------------------------------------------------------------------
# Source 6 | collection_name=cat_health_guidelines_87 | k=16 | score=0.527 | page=13 | start_index=0
# 10 months, primarily by phone contact, and signi ﬁcant ( P , 0.05) reductions in lower urinary tract signs were noted. Although urine-marking behavior and FIC are different condi- tions, the environmental management of both of these elimination problems is similar. T ailoring an environment that is optimal for the indoor cat to reduce urine marking
# --------------------------------------------------------------------------------
# Source 7 | collection_name=cat_health_guidelines_87 | k=16 | score=0.519 | page=19 | start_index=2816
# addressing behavioral needs to improve feline health and wellbeing. J Feline Med Surg 2018;20:1049–55. AAFP Consensus Statement available at: catvets.com/guidelines/practice-guidelines/how-to-feed. 20. AAHA. Body condition scoring (BCS) systems. Available at: http:// aaha.org/globalassets/02-guidelines/weight-management/weightmgmt_ bodyconditionsco
# --------------------------------------------------------------------------------
# Source 8 | collection_name=cat_health_guidelines_87 | k=16 | score=0.518 | page=6 | start_index=4166
# visiting cats, or foster cats from a shelter —and whether the cat at- tends boarding facilities or cat shows. For primarily indoor cats, environmental needs are likewise evaluated. Noting human –cat in- teraction is also important to determine zoonotic risks. 17 For ex- ample, a young adult cat hunting outdoors may need different preventive healthc
# --------------------------------------------------------------------------------
# Source 9 | collection_name=cat_health_guidelines_87 | k=16 | score=0.517 | page=10 | start_index=4208
# study, three 10- to 15-minute exercise sessions per day led to a loss of approximately 1% of body weight in 1 month with no food intake restrictions. 66 Senior Cats Senior cats exhibiting new or unusual behavior should be evaluated for medical conditions. 12 Changes in litter box usage may indicate urinary tract disease, constipation, or diabetes b
# --------------------------------------------------------------------------------
# Source 10 | collection_name=cat_health_guidelines_87 | k=16 | score=0.513 | page=7 | start_index=0
# detection of changes and identi ﬁcation of trends. 20 Obtaining dorsal and lateral photographs of the patient is recommended to facilitate monitoring BCS/MCS as the cat ages, and can help the owner recognize subtle changes. Diseases and conditions that require additional focus during the examination by each life stage are listed in Table 3. Kittens
# --------------------------------------------------------------------------------
# Source 11 | collection_name=cat_health_guidelines_87 | k=16 | score=0.507 | page=6 | start_index=2793
# arousal. If the cat is a new patient to the veterinarian, the client may know from previous experience what works well for their pet. For example, does the cat relax when handled in a towel? What is the cat’s favorite treat? What handling methods have worked well or poorly in the past? This knowledge and an understanding of reduced-stress handling
# --------------------------------------------------------------------------------
# Source 12 | collection_name=cat_health_guidelines_87 | k=16 | score=0.497 | page=20 | start_index=4181
# during transportation and veterinary examination. J Am V et Med Assoc 2017;251:1175–81. 72. Lascelles BDX, Henry JB 3rd, Brown J, et al. Cross-sectional study of the prevalence of radiographic degenerative joint disease in domesticated cats. V et Surg 2010;39:535–44. 73. Gerard AF, Larson M, Baldwin CJ, et al. T elephone survey to investigate relat
# --------------------------------------------------------------------------------
# Source 13 | collection_name=cat_health_guidelines_87 | k=16 | score=0.495 | page=6 | start_index=0
# For example, some senior cats aged 10 years and older may remain in excellent physical condition and would be best treated as a mature adult at the veterinarian ’s discretion. The guidelines are intended to be a starting point from which individualized care recommenda- tions can be developed. Discussion Items for All Life Stages The Task Force reco
# --------------------------------------------------------------------------------
# Source 14 | collection_name=cat_health_guidelines_87 | k=16 | score=0.493 | page=19 | start_index=4171
# 27. Rozanski E. Feline lower airway disease. In: Little S, ed. August’s con- sultations in feline internal medicine . 7th ed. St. Louis (MO): Elsevier; 2016:447–51. 2 8 . E p s t e i nM E ,R o d a nI ,G r i f f e n h a g e nG ,e ta l .2 0 1 5A A H A / A A F Pp a i nm a n - agement guidelines for dogs and cats.J Feline Med Surg 2015;17:251–72. 29. T
# --------------------------------------------------------------------------------
# Source 15 | collection_name=cat_health_guidelines_87 | k=16 | score=0.488 | page=11 | start_index=0
# challenges of diagnosing feline arthritis, it can be dif ﬁcult to tell how many cats are affected. Estimates from published studies suggest that 40–92% of all cats may present with clinical signs associated with DJD. 72 These studies show that arthritis, in addition to being very common in cats, is much more prevalent and severe in older cats, and
# --------------------------------------------------------------------------------
# Source 16 | collection_name=cat_health_guidelines_87 | k=16 | score=0.487 | page=8 | start_index=2767
# sources, scratching posts, and litter boxes. 38 Cats develop patterns of resting and hiding in the home that should be complemented by a variety of appealing places. They may naturally seek their preferred hiding spots if startled or fearful. Some cats prefer to go high, which is consistent with the natural behaviors of the African wild cat, wherea
# --------------------------------------------------------------------------------
# [(Document(metadata={'producer': 'Acrobat Distiller 10.0.0 (Windows)', 'creator': 'Adobe InDesign CS6 (Windows)', 'creationdate': '2021-02-02T08:52:15-05:00', 'author': '7123', 'moddate': '2021-02-02T07:53:51-07:00', 'title': 'djs_jaaha_56_5_COVER.indd', 'source': 'cat_health_guidelines.pdf', 'total_pages': 22, 'page': 7, 'page_label': '8', 'document_type': 'cat_health_guideline', 'start_index': 0, '_id': 'c18359818466457f8eb563803c930f96', '_collection_name': 'cat_health_guidelines_87'}, page_content='Detecting signs of pain or anxiety and evaluation of quality of life\nare most commonly of concern in the mature adult or senior cat but\nmay be relevant at any life stage.\nDuring the physical examination, particular focus is on pain\nassessment and abdominal and thyroid palpation. A detailed mus-\nculoskeletal examination to detect signs of osteoarthritis is critical as\nthis condition is one of the most signi ﬁcant and underdiagnosed\ndiseases in cats.\n23,28 A fundic examination is key to detecting signs of\nophthalmic disease or hypertension. 29 Practices should employ a\nvalidated pain assessment scale or tool to diagnose, monitor, and\nassist in the evaluation of patients for subtle signs of pain.\n30\nChanges in grooming habits, particularly increased grooming,\nmay signal a dermatologic issue such as atopy, food allergy, an\nimmune-mediated skin condition, infectious or parasitic disease,\nendocrine condition, or paraneoplastic syndrome.\n31 Reduced grooming\nby the cat may also indicate underlying illness, bladder pain, degener-\native joint disease (DJD) pain, or reduced mobility.\nBehavior and Environmental Needs\nUnderstanding and Enhancing Behavior by Life Stage\nFeline health and welfare are intricately interrelated at all life stages.\nFrom kitten to senior, an appreciation of the behavioral needs of the\ncat is essential for preventing behavior problems. Problem behaviors\nmay be manifestations of normal feline behaviors, ranging from'), 0.5966206156700201), (Document(metadata={'producer': 'Acrobat Distiller 10.0.0 (Windows)', 'creator': 'Adobe InDesign CS6 (Windows)', 'creationdate': '2021-02-02T08:52:15-05:00', 'author': '7123', 'moddate': '2021-02-02T07:53:51-07:00', 'title': 'djs_jaaha_56_5_COVER.indd', 'source': 'cat_health_guidelines.pdf', 'total_pages': 22, 'page': 6, 'page_label': '7', 'document_type': 'cat_health_guideline', 'start_index': 1395, '_id': '5d8215e64c0b4b029dba4e95d0f8c934', '_collection_name': 'cat_health_guidelines_87'}, page_content='detection of congenital issues such as a heart murmur, hernia, or\ncleft palate. A detailed oral examination is performed to detect\nabnormalities of dentition. The use of fecal scoring charts is very\nhelpful to ensure that the client can accurately identify stool\nconsistency.\n25,26\nYoung Adult Cats\nLower airway disease is common in young adult cats.\n27 Coughing is a\ntypical sign of feline bronchial disease; however, the veterinarian\nmust consider the role of heartworm-associated respiratory disease\n(HARD), transtracheal migration of roundworm ( Toxocara cati ),\nand lungworm. Asking speci ﬁc questions regarding the presence of\ncoughing is helpful for early diagnosis and treatment. Coughing is\nnot typically a hallmark of cardiac disease in cats, in contrast to\ncanine patients, nor is it caused by hairballs. Y oung adult cats de-\nveloping cardiac conditions such as hypertrophic cardiomyopathy\nare often asymptomatic or may display changes in activity level or\nexercise tolerance.\nAsking speci ﬁc questions concerning whether vomiting, vom-\niting hairballs, or diarrhea is occurring, and the frequency of each, is\nrecommended as some clients may consider vomiting or vomiting\nhairballs to be normal for their cat. Additionally, discuss the im-\nportance of monitoring weight, and ask about any chronic enter-\nopathy or gastrointestinal (GI) signs that could indicate early stages of\ndisease.\nMature Adult and Senior Cats\nThe medical history and exa ...
# --------------------------------------------------------------------------------

# %% [markdown]
# ### 🏗️ Activity Notes
#
# - Setting changed:
#
# I tested 5 chunk configurations on the cat health PDF (22 pages):
#
# | Collection key	| Chunks	| Config (size, overlap) |
# | :--- | :---: | ---: |
# | Left-aligned text | Centered text | Right-aligned text |
# | cat_health_guidelines_135 | 135 |  1000 / 200 (baseline) |
# | cat_health_guidelines_500 | 500 | 500 / 300 |
# | cat_health_guidelines_263 | 263 | 500 / 100 |
# | cat_health_guidelines_91  |  91 |  1500 / 300 |
# | cat_health_guidelines_87  | 87  | 1500 / 100 |
#
# For each collection I ran retrieval with k = 4, 8, 12, 16 using:
#
# "What are signs that my cat may need veterinary attention?"
#
#
# - Before:
#
# > Baseline 1000/200, k=4
#
#
#
# - After:
#
# > 1500/300 or 1500/100, k=4
#
#
#
#
# - Did retrieval improve? Why or why not?
#
# > Slightly at the margins — top hit was stable, but larger chunks gave better ranks 2–4; higher k added noise without improving the best chunks.
#
# ## Main Observations:
#
# chunk size had a small effect; k had almost none on the top results
#
# For every configuration, Source 1 scored about 0.596–0.597 and came from page 8 — the section on pain/anxiety, grooming changes, and exam focus for mature/senior cats.
#
# That means for this query, changing chunk size did not dramatically change what ranked first. The embedding model consistently found the same high-value passage.
#
# Larger chunks (1500) gave slightly richer top hits. Very small chunks with heavy overlap (500/300) created the most chunks and did not clearly improve relevance.
#
# ## Testing with different k:
#
# Increasing k did not improve the best context — it added noise
#
# Within each collection, the top 4 chunks were identical for k=4, 8, 12, and 16.
#
# Only when k went beyond 4 did lower-scoring chunks appear, such as:
#
# Kitten behavior discussion (page 7)
# Play/exercise/weight content (page 10)
# Bibliography/references (pages 18–20)
# Stress/fear body language (less directly about “when to see a vet”)
# Takeaway: For this question, k=4 was enough. Higher k mostly added marginally related or off-topic chunks, which could dilute the LLM context.
#
# So retrieval quality was good for k=4 across configs; the tradeoff was precision vs. noise, not “can’t find the answer.”
#
# ## Practical Conclusion:
#
# For this  this cat health document PDF:
#
# Best balance: 1500 / 300 or 1500 / 100 — slightly stronger or equally strong top hits with good supporting chunks.
# Safe default: 1000 / 200 with k=4 — nearly as good, simpler, fewer chunks.
# Avoid: 500 / 300 — many tiny overlapping chunks without clear retrieval gain.
# k tuning: Higher k did not improve top relevance.
